# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#     land  price
# 0   1000   2245
# 1   2000   4575
# 2   3000   6874
# 3   4000   8878
# 4   5000  10000
# 5   6000  12457
# 6   7000  14785
# 7   8000  16785
# 8  10000  20789

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.land, df.price, color = 'red')
plt.plot(df.land, reg.predict(df[['land']]), color = 'blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['land']], df.price)
# Out:
# LinearRegression()

# %%
prediction_input = pd.DataFrame({'land': [9000]})
reg.predict(prediction_input)
# Out:
# array([18734.])

# %%
reg.coef_
# Out:
# array([2.0348])

# %%
reg.intercept_
# Out:
# 420.8000000000029

# %%
2.0348*9000 + 420.8000000000029
# Out:
# 18734.000000000004

# %%
import pickle

# %%
with open('model_land_price_predict', 'wb') as f:
    pickle.dump(reg, f)

# %%
with open('model_land_price_predict', 'rb') as f:
    mp = pickle.load(f)

# %%
prediction_input = pd.DataFrame({'land': [9000]})
mp.predict(prediction_input)
# Out:
# array([18734.])
